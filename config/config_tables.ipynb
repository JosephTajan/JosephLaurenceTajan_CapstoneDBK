# %%
# %run ./config_init

# %%
configurations_table_query = f"""
    CREATE TABLE IF NOT EXISTS {catalog_name}.{schema_config}.configurations_table (
        domain_name STRING,
        medallion_layer STRING,
        stage STRING,
        operation STRING,
        source_type STRING,
        source STRING,
        source_keys STRING,
        target STRING,
        target_keys STRING
    )
"""

try:
    create_table(configurations_table_query)
    print(f"Created table from {configurations_table_query}")
except Exception as error:
    print(f"Error creating table: {error}")

# %%
bronze_table_list = []

bt_claims_batch_query = f"""
    CREATE TABLE IF NOT EXISTS {catalog_name}.{schema_bronze}.bt_fact_claims_batch (
        ClaimID STRING,
        MemberID STRING,
        ProviderID STRING,
        ClaimDate STRING,
        ServiceDate STRING,
        Amount STRING,
        Status STRING,
        ICD10Codes STRING,
        CPTCodes STRING,
        ClaimType STRING,
        SubmissionChannel STRING,
        Notes STRING,
        IngestTimestamp STRING,
        create_date STRING,
        source_name STRING,
        meta_job_id STRING,
        meta_job_run_id STRING,
        meta_task_run_id STRING,
        meta_orchestrator_job_id STRING,
        meta_orchestrator_job_run_id STRING
    )
"""
bronze_table_list.append(bt_claims_batch_query)

bt_claims_stream_query = f"""
    CREATE TABLE IF NOT EXISTS {catalog_name}.{schema_bronze}.bt_fact_claims_stream (
        ClaimID STRING,
        MemberID STRING,
        ProviderID STRING,
        ClaimDate STRING,
        Amount STRING,
        Status STRING,
        ICD10Codes STRING,
        CPTCodes STRING,
        EventTimestamp STRING,
        create_date STRING,
        source_name STRING,
        meta_job_id STRING,
        meta_job_run_id STRING,
        meta_task_run_id STRING,
        meta_orchestrator_job_id STRING,
        meta_orchestrator_job_run_id STRING
    )
"""
bronze_table_list.append(bt_claims_stream_query)

bt_diagnosis_query = f"""
    CREATE TABLE IF NOT EXISTS {catalog_name}.{schema_bronze}.bt_ref_diagnosis (
        Code STRING,
        Description STRING,
        create_date STRING,
        source_name STRING,
        meta_job_id STRING,
        meta_job_run_id STRING,
        meta_task_run_id STRING,
        meta_orchestrator_job_id STRING,
        meta_orchestrator_job_run_id STRING
    )
"""
bronze_table_list.append(bt_diagnosis_query)

bt_members_query = f"""
    CREATE TABLE IF NOT EXISTS {catalog_name}.{schema_bronze}.bt_fact_members (
        MemberID STRING,
        Name STRING,
        DOB STRING,
        Gender STRING,
        Region STRING,
        PlanType STRING,
        EffectiveDate STRING,
        Email STRING,
        IsActive STRING,
        LastUpdated STRING,
        create_date STRING,
        source_name STRING,
        meta_job_id STRING,
        meta_job_run_id STRING,
        meta_task_run_id STRING,
        meta_orchestrator_job_id STRING,
        meta_orchestrator_job_run_id STRING
    )
"""
bronze_table_list.append(bt_members_query)

bt_providers_query = f"""
    CREATE TABLE IF NOT EXISTS {catalog_name}.{schema_bronze}.bt_fact_providers (
        ProviderID STRING,
        Name STRING,
        Specialties STRING,
        Locations STRING,
        IsActive STRING,
        TIN STRING,
        LastVerified STRING,
        create_date STRING,
        source_name STRING,
        meta_job_id STRING,
        meta_job_run_id STRING,
        meta_task_run_id STRING,
        meta_orchestrator_job_id STRING,
        meta_orchestrator_job_run_id STRING
    )
"""
bronze_table_list.append(bt_providers_query)

try:
    for query in bronze_table_list:
        create_table(query)
        print(f"Created table from {query}")
except Exception as error:
    print(f"Error creating table: {error}")

# %%
silver_table_list = []

st_claims_batch_query = f"""
    CREATE TABLE IF NOT EXISTS {catalog_name}.{schema_silver}.st_fact_claims_batch (
        ClaimID STRING,
        MemberID STRING,
        ProviderID STRING,
        ClaimDate DATE,
        ServiceDate DATE,
        Amount DOUBLE,
        Status STRING,
        ICD10Codes STRING,
        CPTCodes STRING,
        ClaimType STRING,
        SubmissionChannel STRING,
        Notes STRING,
        IngestTimestamp TIMESTAMP,
        create_date TIMESTAMP,
        source_name STRING,
        meta_job_id STRING,
        meta_job_run_id STRING,
        meta_task_run_id STRING,
        meta_orchestrator_job_id STRING,
        meta_orchestrator_job_run_id STRING
    )
"""
silver_table_list.append(st_claims_batch_query)

st_claims_stream_query = f"""
    CREATE TABLE IF NOT EXISTS {catalog_name}.{schema_silver}.st_fact_claims_stream (
        ClaimID STRING,
        MemberID STRING,
        ProviderID STRING,
        ClaimDate DATE,
        Amount DOUBLE,
        Status STRING,
        ICD10Codes STRING,
        CPTCodes STRING,
        EventTimestamp TIMESTAMP,
        create_date TIMESTAMP,
        source_name STRING,
        meta_job_id STRING,
        meta_job_run_id STRING,
        meta_task_run_id STRING,
        meta_orchestrator_job_id STRING,
        meta_orchestrator_job_run_id STRING
    )
"""
silver_table_list.append(st_claims_stream_query)

st_diagnosis_query = f"""
    CREATE TABLE IF NOT EXISTS {catalog_name}.{schema_silver}.st_ref_diagnosis (
        Code STRING,
        Description STRING,
        create_date TIMESTAMP,
        source_name STRING,
        meta_job_id STRING,
        meta_job_run_id STRING,
        meta_task_run_id STRING,
        meta_orchestrator_job_id STRING,
        meta_orchestrator_job_run_id STRING
    )
"""
silver_table_list.append(st_diagnosis_query)

st_members_query = f"""
    CREATE TABLE IF NOT EXISTS {catalog_name}.{schema_silver}.st_fact_members (
        MemberID STRING,
        Name STRING,
        DOB STRING,
        Gender STRING,
        Region STRING,
        PlanType STRING,
        EffectiveDate DATE,
        Email STRING,
        IsActive STRING,
        LastUpdated DATE,
        create_date TIMESTAMP,
        source_name STRING,
        meta_job_id STRING,
        meta_job_run_id STRING,
        meta_task_run_id STRING,
        meta_orchestrator_job_id STRING,
        meta_orchestrator_job_run_id STRING
    )
"""
silver_table_list.append(st_members_query)

st_providers_query = f"""
    CREATE TABLE IF NOT EXISTS {catalog_name}.{schema_silver}.st_fact_providers (
        ProviderID STRING,
        Name STRING,
        Specialties STRING,
        Locations STRING,
        IsActive STRING,
        TIN STRING,
        LastVerified STRING,
        create_date TIMESTAMP,
        source_name STRING,
        meta_job_id STRING,
        meta_job_run_id STRING,
        meta_task_run_id STRING,
        meta_orchestrator_job_id STRING,
        meta_orchestrator_job_run_id STRING
    )
"""
silver_table_list.append(st_providers_query)

try:
    for query in silver_table_list:
        create_table(query)
        print(f"Created table from {query}")
except Exception as error:
    print(f"Error creating table: {error}")

# %%
silver_table_list_transformed = []

st_claims_batch_transformed_query = f"""
    CREATE TABLE IF NOT EXISTS {catalog_name}.{schema_silver}.st_fact_claims_batch_transformed (
        ClaimID STRING,
        MemberID STRING,
        ProviderID STRING,
        ClaimDate DATE,
        ServiceDate DATE,
        Amount DOUBLE,
        Status STRING,
        ICD10Codes STRING,
        CPTCodes STRING,
        ClaimType STRING,
        SubmissionChannel STRING,
        Notes STRING,
        ClaimDetection STRING,
        IngestTimestamp TIMESTAMP,
        create_date TIMESTAMP,
        source_name STRING,
        meta_job_id STRING,
        meta_job_run_id STRING,
        meta_task_run_id STRING,
        meta_orchestrator_job_id STRING,
        meta_orchestrator_job_run_id STRING
    )
"""
silver_table_list_transformed.append(st_claims_batch_transformed_query)

# st_claims_stream_transformed_query = f"""
#     CREATE TABLE IF NOT EXISTS {catalog_name}.{schema_silver}.st_fact_claims_stream_transformed (
#         ClaimID STRING,
#         MemberID STRING,
#         ProviderID STRING,
#         ClaimDate DATE,
#         Amount DOUBLE,
#         Status STRING,
#         ICD10Codes STRING,
#         CPTCodes STRING,
#         EventTimestamp TIMESTAMP,
#         create_date TIMESTAMP,
#         source_name STRING,
#         meta_job_id STRING,
#         meta_job_run_id STRING,
#         meta_task_run_id STRING,
#         meta_orchestrator_job_id STRING,
#         meta_orchestrator_job_run_id STRING
#     )
# """
# silver_table_list_transformed.append(st_claims_stream_transformed_query)

# st_diagnosis_transformed_query = f"""
#     CREATE TABLE IF NOT EXISTS {catalog_name}.{schema_silver}.st_ref_diagnosis_transformed (
#         Code STRING,
#         Description STRING,
#         create_date TIMESTAMP,
#         source_name STRING,
#         meta_job_id STRING,
#         meta_job_run_id STRING,
#         meta_task_run_id STRING,
#         meta_orchestrator_job_id STRING,
#         meta_orchestrator_job_run_id STRING
#     )
# """
# silver_table_list_transformed.append(st_diagnosis_transformed_query)

# st_members_transformed_query = f"""
#     CREATE TABLE IF NOT EXISTS {catalog_name}.{schema_silver}.st_fact_members_transformed (
#         MemberID STRING,
#         Name STRING,
#         DOB STRING,
#         Gender STRING,
#         Region STRING,
#         PlanType STRING,
#         EffectiveDate STRING,
#         Email STRING,
#         IsActive STRING,
#         LastUpdated STRING,
#         create_date TIMESTAMP,
#         source_name STRING,
#         meta_job_id STRING,
#         meta_job_run_id STRING,
#         meta_task_run_id STRING,
#         meta_orchestrator_job_id STRING,
#         meta_orchestrator_job_run_id STRING
#     )
# """
# silver_table_list_transformed.append(st_members_transformed_query)

# st_providers_transformed_query = f"""
#     CREATE TABLE IF NOT EXISTS {catalog_name}.{schema_silver}.st_fact_providers_transformed (
#         ProviderID STRING,
#         Name STRING,
#         Specialties STRING,
#         Locations STRING,
#         IsActive STRING,
#         TIN STRING,
#         LastVerified STRING,
#         create_date TIMESTAMP,
#         source_name STRING,
#         meta_job_id STRING,
#         meta_job_run_id STRING,
#         meta_task_run_id STRING,
#         meta_orchestrator_job_id STRING,
#         meta_orchestrator_job_run_id STRING
#     )
# """
# silver_table_list_transformed.append(st_providers_transformed_query)

try:
    for query in silver_table_list_transformed:
        create_table(query)
        print(f"Created table from {query}")
except Exception as error:
    print(f"Error creating table: {error}")

# %%
gold_table_list = []

gt_claims_batch_query = f"""
    CREATE TABLE IF NOT EXISTS {catalog_name}.{schema_gold}.gt_fact_claims_batch (
        ClaimID STRING,
        MemberID STRING,
        ProviderID STRING,
        ClaimDate DATE,
        ServiceDate DATE,
        Amount DOUBLE,
        Status STRING,
        ICD10Codes STRING,
        CPTCodes STRING,
        ClaimType STRING,
        SubmissionChannel STRING,
        Notes STRING,
        ClaimDetection STRING,
        IngestTimestamp TIMESTAMP,
        create_date TIMESTAMP,
        source_name STRING,
        meta_job_id STRING,
        meta_job_run_id STRING,
        meta_task_run_id STRING,
        meta_orchestrator_job_id STRING,
        meta_orchestrator_job_run_id STRING
    )
"""
gold_table_list.append(gt_claims_batch_query)

gt_claims_stream_query = f"""
    CREATE TABLE IF NOT EXISTS {catalog_name}.{schema_gold}.gt_fact_claims_stream (
        ClaimID STRING,
        MemberID STRING,
        ProviderID STRING,
        ClaimDate DATE,
        Amount DOUBLE,
        Status STRING,
        ICD10Codes STRING,
        CPTCodes STRING,
        EventTimestamp TIMESTAMP,
        create_date TIMESTAMP,
        source_name STRING,
        meta_job_id STRING,
        meta_job_run_id STRING,
        meta_task_run_id STRING,
        meta_orchestrator_job_id STRING,
        meta_orchestrator_job_run_id STRING
    )
"""
gold_table_list.append(gt_claims_stream_query)

gt_diagnosis_query = f"""
    CREATE TABLE IF NOT EXISTS {catalog_name}.{schema_gold}.gt_ref_diagnosis (
        Code STRING,
        Description STRING,
        create_date TIMESTAMP,
        source_name STRING,
        meta_job_id STRING,
        meta_job_run_id STRING,
        meta_task_run_id STRING,
        meta_orchestrator_job_id STRING,
        meta_orchestrator_job_run_id STRING
    )
"""
gold_table_list.append(gt_diagnosis_query)

gt_members_query = f"""
    CREATE TABLE IF NOT EXISTS {catalog_name}.{schema_gold}.gt_fact_members (
        MemberID STRING,
        Name STRING,
        DOB STRING,
        Gender STRING,
        Region STRING,
        PlanType STRING,
        EffectiveDate DATE,
        Email STRING,
        IsActive STRING,
        LastUpdated DATE,
        create_date TIMESTAMP,
        source_name STRING,
        meta_job_id STRING,
        meta_job_run_id STRING,
        meta_task_run_id STRING,
        meta_orchestrator_job_id STRING,
        meta_orchestrator_job_run_id STRING
    )
"""
gold_table_list.append(gt_members_query)

gt_providers_query = f"""
    CREATE TABLE IF NOT EXISTS {catalog_name}.{schema_gold}.gt_fact_providers (
        ProviderID STRING,
        Name STRING,
        Specialties STRING,
        Locations STRING,
        IsActive STRING,
        TIN STRING,
        LastVerified STRING,
        create_date TIMESTAMP,
        source_name STRING,
        meta_job_id STRING,
        meta_job_run_id STRING,
        meta_task_run_id STRING,
        meta_orchestrator_job_id STRING,
        meta_orchestrator_job_run_id STRING
    )
"""
gold_table_list.append(gt_providers_query)

try:
    for query in gold_table_list:
        create_table(query)
        print(f"Created table from {query}")
except Exception as error:
    print(f"Error creating table: {error}")
